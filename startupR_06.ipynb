# %% [markdown]
# # 第６章 環境
# ざっくりとディレクトリ操作について。
# そんなに使うのかなぁ。

# %% [markdown]
# これまでの章で使用した`shuffle関数`は実際にdeckをシャッフルしている訳ではありません。<br>
# 本当はシャッフルされたdeckをコピーしたものを返しているだけなのです。<br>
# 本章ではdeck自体を操作してシャッフルを行いタイト思います。

# %%
install.packages("pryr")
library(pryr)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
parenvs(all =TRUE)
# Out:
#    label                            name
# 1  <environment: R_GlobalEnv>       ""
# 2  <environment: package:pryr>      "package:pryr"
# 3  <environment: 0x564afc9ddfd8>    "jupyter:irkernel"
# 4  <environment: package:stats>     "package:stats"
# 5  <environment: package:graphics>  "package:graphics"
# 6  <environment: package:grDevices> "package:grDevices"
# 7  <environment: package:utils>     "package:utils"
# 8  <environment: package:datasets>  "package:datasets"
# 9  <environment: package:methods>   "package:methods"
# 10 <environment: 0x564afbe48838>    "Autoloads"
# 11 <environment: base>              ""
# 12 <environment: R_EmptyEnv>        ""

# %% [markdown]
# ## 6.2 環境の操作

# %% [markdown]
# `as.environment()`は引数として環境名を入れることで、<br>
# ディレクトリに関する情報を得ることができる。

# %%
as.environment("package:stats")
# Out:
# <environment: package:stats>
# attr(,"name")
# [1] "package:stats"
# attr(,"path")
# [1] "/opt/conda/lib/R/library/stats"

# %%
globalenv() #グローバル環境
baseenv() #ベース環境
emptyenv()# 空環境
# Out:
# <environment: R_GlobalEnv>
# <environment: base>
# <environment: R_EmptyEnv>

# %% [markdown]
# `pearent.ev()`を使用することで親環境をみることができる。

# %%
parent.env(globalenv())
# Out:
# <environment: package:pryr>
# attr(,"name")
# [1] "package:pryr"
# attr(,"path")
# [1] "/opt/conda/lib/R/library/pryr"

# %% [markdown]
# 空環境は親がない環境

# %%
parent.env(emptyenv())
# Out:
# Error in parent.env(emptyenv()): the empty environment has no parent
# Traceback:
#
# 1. parent.env(emptyenv())

# %% [markdown]
# 格納されているオブジェクトは　`ls()` か`ls.str()`で出力。

# %%
ls(emptyenv())
# Out:
# character(0)

# %%
a <- "hello"
ls(globalenv())
# Out:
# [1] "a"

# %%
ls(baseenv())
# Out:
#    [1] "-"                                  "-.Date"
#    [3] "-.POSIXt"                           ":"
#    [5] "::"                                 ":::"
#    [7] "!"                                  "!.hexmode"
#    [9] "!.octmode"                          "!="
#   [11] "("                                  "["
#   [13] "[.AsIs"                             "[.data.frame"
#   [15] "[.Date"                             "[.difftime"
#   [17] "[.Dlist"                            "[.DLLInfoList"
#   [19] "[.factor"                           "[.hexmode"
#   [21] "[.listof"                           "[.noquote"
#   [23] "[.numeric_version"                  "[.octmode"
#   [25] "[.POSIXct"                          "[.POSIXlt"
#   [27] "[.simple.list"                      "[.table"
#   [29] "[.warnings"                         "[["
#   [31] "[[.data.frame"                      "[[.Date"
#   [33] "[[.factor"                          "[[.numeric_version"
#   [35] "[[.POSIXct"                         "[[.POSIXlt"
#   [37] "[[<-"                               "[[<-.data.frame"
#   [39] "[[<-.factor"                        "[[<-.numeric_version"
#   [41] "[<-"                                "[<-.data.frame"
#   [43] "[<-.Date"                           "[<-.factor"
#   [45] "[<-.numeric_version"                "[<-.POSIXct"
#   [47] "[<-.POSIXlt"                        "{"
#   [49] "@"                                  "@<-"
#   [51] "*"                                  "*.difftime"
#   [53] "/"                                  "/.difftime"
#   [55] "&"                                  "&.hexmode"
#   [57] "&.octmode"                          "&&"
#   [59] "%*%"                                "%/%"
#   [61] "%%"                                 "%in%"
#   [63] "%o%"                                "%x%"
#   [65] "^"                                  "+"
#   [67] "+.Date"                             "+.POSIXt"
#   [69] "<"                                  "<-"
#   [71] "<<-"                                "<="
#   [73] "="                                  "=="
#   [75] ">"                                  ">="
#   [77] "|"                                  "|.hexmode"
#   [79] "|.octmode"                          "||"
#   [81] "~"                                  "$"
#   [83] "$.data.frame"                       "$.DLLInfo"
#   [85] "$.package_version"                  "$<-"
#   [87] "$<-.data.frame"                     "abbreviate"
#   [89] "abs"                                "acos"
#   [91] "acosh"                              "addNA"
#   [93] "addTaskCallback"                    "agrep"
#   [95] "agrepl"                             "alist"
#   [97] "all"                                "all.equal"
#   [99] "all.equal.character"                "all.equal.default"
#  [101] "all.equal.environment"              "all.equal.envRefClass"
#  [103] "all.equal.factor"                   "all.equal.formula"
#  [105] "all.equal.language"                 "all.equal.list"
#  [107] "all.equal.numeric"                  "all.equal.POSIXt"
#  [109] "all.equal.raw"                      "all.names"
#  [111] "all.vars"                           "allowInterrupts"
#  [113] "any"                                "anyDuplicated"
#  [115] "anyDuplicated.array"                "anyDuplicated.data.frame"
#  [117] "anyDuplicated.default"              "anyDuplicated.matrix"
#  [119] "anyNA"                              "anyNA.numeric_version"
#  [121] "anyNA.POSIXlt"                      "aperm"
#  [123] "aperm.default"                      "aperm.table"
#  [125] "append"                             "apply"
#  [127] "Arg"                                "args"
#  [129] "array"                              "arrayInd"
#  [131] "as.array"                           "as.array.default"
#  [133] "as.call"                            "as.character"
#  [135] "as.character.condition"             "as.character.Date"
#  [137] "as.character.default"               "as.character.error"
#  [139] "as.character.factor"                "as.character.hexmode"
#  [141] "as.character.numeric_version"       "as.character.octmode"
#  [143] "as.character.POSIXt"                "as.character.srcref"
#  [145] "as.complex"                         "as.data.frame"
#  [147] "as.data.frame.array"                "as.data.frame.AsIs"
#  [149] "as.data.frame.character"            "as.data.frame.complex"
#  [151] "as.data.frame.data.frame"           "as.data.frame.Date"
#  [153] "as.data.frame.default"              "as.data.frame.difftime"
#  [155] "as.data.frame.factor"               "as.data.frame.integer"
#  [157] "as.data.frame.list"                 "as.data.frame.logical"
#  [159] "as.data.frame.matrix"               "as.data.frame.model.matrix"
#  [161] "as.data.frame.noquote"              "as.data.frame.numeric"
#  [163] "as.data.frame.numeric_version"      "as.data.frame.ordered"
#  [165] "as.data.frame.POSIXct"              "as.data.frame.POSIXlt"
#  [167] "as.data.frame.raw"                  "as.data.frame.table"
#  [169] "as.data.frame.ts"                   "as.data.frame.vector"
#  [171] "as.Date"                            "as.Date.character"
#  [173] "as.Date.default"                    "as.Date.factor"
#  [175] "as.Date.numeric"                    "as.Date.POSIXct"
#  [177] "as.Date.POSIXlt"                    "as.difftime"
#  [179] "as.double"                          "as.double.difftime"
#  [181] "as.double.POSIXlt"                  "as.environment"
#  [183] "as.expression"                      "as.expression.default"
#  [185] "as.factor"                          "as.function"
#  [187] "as.function.default"                "as.hexmode"
#  [189] "as.integer"                         "as.list"
#  [191] "as.list.data.frame"                 "as.list.Date"
#  [193] "as.list.default"                    "as.list.environment"
#  [195] "as.list.factor"                     "as.list.function"
#  [197] "as.list.numeric_version"            "as.list.POSIXct"
#  [199] "as.list.POSIXlt"                    "as.logical"
#  [201] "as.logical.factor"                  "as.matrix"
#  [203] "as.matrix.data.frame"               "as.matrix.default"
#  [205] "as.matrix.noquote"                  "as.matrix.POSIXlt"
#  [207] "as.name"                            "as.null"
#  [209] "as.null.default"                    "as.numeric"
#  [211] "as.numeric_version"                 "as.octmode"
#  [213] "as.ordered"                         "as.package_version"
#  [215] "as.pairlist"                        "as.POSIXct"
#  [217] "as.POSIXct.Date"                    "as.POSIXct.default"
#  [219] "as.POSIXct.numeric"                 "as.POSIXct.POSIXlt"
#  [221] "as.POSIXlt"                         "as.POSIXlt.character"
#  [223] "as.POSIXlt.Date"                    "as.POSIXlt.default"
#  [225] "as.POSIXlt.factor"                  "as.POSIXlt.numeric"
#  [227] "as.POSIXlt.POSIXct"                 "as.qr"
#  [229] "as.raw"                             "as.single"
#  [231] "as.single.default"                  "as.symbol"
#  [233] "as.table"                           "as.table.default"
#  [235] "as.vector"                          "as.vector.factor"
#  [237] "asin"                               "asinh"
#  [239] "asNamespace"                        "asS3"
#  [241] "asS4"                               "assign"
#  [243] "atan"                               "atan2"
#  [245] "atanh"                              "attach"
#  [247] "attachNamespace"                    "attr"
#  [249] "attr.all.equal"                     "attr<-"
#  [251] "attributes"                         "attributes<-"
#  [253] "autoload"                           "autoloader"
#  [255] "backsolve"                          "baseenv"
#  [257] "basename"                           "besselI"
#  [259] "besselJ"                            "besselK"
#  [261] "besselY"                            "beta"
#  [263] "bindingIsActive"                    "bindingIsLocked"
#  [265] "bindtextdomain"                     "bitwAnd"
#  [267] "bitwNot"                            "bitwOr"
#  [269] "bitwShiftL"                         "bitwShiftR"
#  [271] "bitwXor"                            "body"
#  [273] "body<-"                             "bquote"
#  [275] "break"                              "browser"
#  [277] "browserCondition"                   "browserSetDebug"
#  [279] "browserText"                        "builtins"
#  [281] "by"                                 "by.data.frame"
#  [283] "by.default"                         "bzfile"
#  [285] "c"                                  "c.Date"
#  [287] "c.difftime"                         "c.noquote"
#  [289] "c.numeric_version"                  "c.POSIXct"
#  [291] "c.POSIXlt"                          "c.warnings"
#  [293] "call"                               "callCC"
#  [295] "capabilities"                       "casefold"
#  [297] "cat"                                "cbind"
#  [299] "cbind.data.frame"                   "ceiling"
#  [301] "char.expand"                        "character"
#  [303] "charmatch"                          "charToRaw"
#  [305] "chartr"                             "check_tzones"
#  [307] "chkDots"                            "chol"
#  [309] "chol.default"                       "chol2inv"
#  [311] "choose"                             "class"
#  [313] "class<-"                            "clearPushBack"
#  [315] "close"                              "close.connection"
#  [317] "close.srcfile"                      "close.srcfilealias"
#  [319] "closeAllConnections"                "col"
#  [321] "colMeans"                           "colnames"
#  [323] "colnames<-"                         "colSums"
#  [325] "commandArgs"                        "comment"
#  [327] "comment<-"                          "complex"
#  [329] "computeRestarts"                    "conditionCall"
#  [331] "conditionCall.condition"            "conditionMessage"
#  [333] "conditionMessage.condition"         "conflicts"
#  [335] "Conj"                               "contributors"
#  [337] "cos"                                "cosh"
#  [339] "cospi"                              "crossprod"
#  [341] "Cstack_info"                        "cummax"
#  [343] "cummin"                             "cumprod"
#  [345] "cumsum"                             "curlGetHeaders"
#  [347] "cut"                                "cut.Date"
#  [349] "cut.default"                        "cut.POSIXt"
#  [351] "data.class"                         "data.frame"
#  [353] "data.matrix"                        "date"
#  [355] "debug"                              "debuggingState"
#  [357] "debugonce"                          "default.stringsAsFactors"
#  [359] "delayedAssign"                      "deparse"
#  [361] "det"                                "detach"
#  [363] "determinant"                        "determinant.matrix"
#  [365] "dget"                               "diag"
#  [367] "diag<-"                             "diff"
#  [369] "diff.Date"                          "diff.default"
#  [371] "diff.difftime"                      "diff.POSIXt"
#  [373] "difftime"                           "digamma"
#  [375] "dim"                                "dim.data.frame"
#  [377] "dim<-"                              "dimnames"
#  [379] "dimnames.data.frame"                "dimnames<-"
#  [381] "dimnames<-.data.frame"              "dir"
#  [383] "dir.create"                         "dir.exists"
#  [385] "dirname"                            "do.call"
#  [387] "dontCheck"                          "double"
#  [389] "dput"                               "dQuote"
#  [391] "drop"                               "droplevels"
#  [393] "droplevels.data.frame"              "droplevels.factor"
#  [395] "dump"                               "duplicated"
#  [397] "duplicated.array"                   "duplicated.data.frame"
#  [399] "duplicated.default"                 "duplicated.matrix"
#  [401] "duplicated.numeric_version"         "duplicated.POSIXlt"
#  [403] "duplicated.warnings"                "dyn.load"
#  [405] "dyn.unload"                         "dynGet"
#  [407] "eapply"                             "eigen"
#  [409] "emptyenv"                           "enc2native"
#  [411] "enc2utf8"                           "encodeString"
#  [413] "Encoding"                           "Encoding<-"
#  [415] "endsWith"                           "enquote"
#  [417] "env.profile"                        "environment"
#  [419] "environment<-"                      "environmentIsLocked"
#  [421] "environmentName"                    "eval"
#  [423] "eval.parent"                        "evalq"
#  [425] "exists"                             "exp"
#  [427] "expand.grid"                        "expm1"
#  [429] "expression"                         "extSoftVersion"
#  [431] "F"                                  "factor"
#  [433] "factorial"                          "fifo"
#  [435] "file"                               "file.access"
#  [437] "file.append"                        "file.choose"
#  [439] "file.copy"                          "file.create"
#  [441] "file.exists"                        "file.info"
#  [443] "file.link"                          "file.mode"
#  [445] "file.mtime"                         "file.path"
#  [447] "file.remove"                        "file.rename"
#  [449] "file.show"                          "file.size"
#  [451] "file.symlink"                       "Filter"
#  [453] "Find"                               "find.package"
#  [455] "findInterval"                       "findPackageEnv"
#  [457] "findRestart"                        "floor"
#  [459] "flush"                              "flush.connection"
#  [461] "for"                                "force"
#  [463] "forceAndCall"                       "formals"
#  [465] "formals<-"                          "format"
#  [467] "format.AsIs"                        "format.data.frame"
#  [469] "format.Date"                        "format.default"
#  [471] "format.difftime"                    "format.factor"
#  [473] "format.hexmode"                     "format.info"
#  [475] "format.libraryIQR"                  "format.numeric_version"
#  [477] "format.octmode"                     "format.packageInfo"
#  [479] "format.POSIXct"                     "format.POSIXlt"
#  [481] "format.pval"                        "format.summaryDefault"
#  [483] "formatC"                            "formatDL"
#  [485] "forwardsolve"                       "function"
#  [487] "gamma"                              "gc"
#  [489] "gc.time"                            "gcinfo"
#  [491] "gctorture"                          "gctorture2"
#  [493] "get"                                "get0"
#  [495] "getAllConnections"                  "getCallingDLL"
#  [497] "getCallingDLLe"                     "getConnection"
#  [499] "getDLLRegisteredRoutines"           "getDLLRegisteredRoutines.character"
#  [501] "getDLLRegisteredRoutines.DLLInfo"   "getElement"
#  [503] "geterrmessage"                      "getExportedValue"
#  [505] "getHook"                            "getLoadedDLLs"
#  [507] "getNamespace"                       "getNamespaceExports"
#  [509] "getNamespaceImports"                "getNamespaceInfo"
#  [511] "getNamespaceName"                   "getNamespaceUsers"
#  [513] "getNamespaceVersion"                "getNativeSymbolInfo"
#  [515] "getOption"                          "getRversion"
#  [517] "getSrcLines"                        "getTaskCallbackNames"
#  [519] "gettext"                            "gettextf"
#  [521] "getwd"                              "gl"
#  [523] "globalenv"                          "gregexpr"
#  [525] "grep"                               "grepl"
#  [527] "grepRaw"                            "grouping"
#  [529] "gsub"                               "gzcon"
#  [531] "gzfile"                             "I"
#  [533] "iconv"                              "iconvlist"
#  [535] "icuGetCollate"                      "icuSetCollate"
#  [537] "identical"                          "identity"
#  [539] "if"                                 "ifelse"
#  [541] "Im"                                 "importIntoEnv"
#  [543] "inherits"                           "integer"
#  [545] "interaction"                        "interactive"
#  [547] "intersect"                          "intToBits"
#  [549] "intToUtf8"                          "inverse.rle"
#  [551] "invisible"                          "invokeRestart"
#  [553] "invokeRestartInteractively"         "is.array"
#  [555] "is.atomic"                          "is.call"
#  [557] "is.character"                       "is.complex"
#  [559] "is.data.frame"                      "is.double"
#  [561] "is.element"                         "is.environment"
#  [563] "is.expression"                      "is.factor"
#  [565] "is.finite"                          "is.function"
#  [567] "is.infinite"                        "is.integer"
#  [569] "is.language"                        "is.list"
#  [571] "is.loaded"                          "is.logical"
#  [573] "is.matrix"                          "is.na"
#  [575] "is.na.data.frame"                   "is.na.numeric_version"
#  [577] "is.na.POSIXlt"                      "is.na<-"
#  [579] "is.na<-.default"                    "is.na<-.factor"
#  [581] "is.na<-.numeric_version"            "is.name"
#  [583] "is.nan"                             "is.null"
#  [585] "is.numeric"                         "is.numeric_version"
#  [587] "is.numeric.Date"                    "is.numeric.difftime"
#  [589] "is.numeric.POSIXt"                  "is.object"
#  [591] "is.ordered"                         "is.package_version"
#  [593] "is.pairlist"                        "is.primitive"
#  [595] "is.qr"                              "is.R"
#  [597] "is.raw"                             "is.recursive"
#  [599] "is.single"                          "is.symbol"
#  [601] "is.table"                           "is.unsorted"
#  [603] "is.vector"                          "isatty"
#  [605] "isBaseNamespace"                    "isdebugged"
#  [607] "isFALSE"                            "isIncomplete"
#  [609] "isNamespace"                        "isNamespaceLoaded"
#  [611] "ISOdate"                            "ISOdatetime"
#  [613] "isOpen"                             "isRestart"
#  [615] "isS4"                               "isSeekable"
#  [617] "isSymmetric"                        "isSymmetric.matrix"
#  [619] "isTRUE"                             "jitter"
#  [621] "julian"                             "julian.Date"
#  [623] "julian.POSIXt"                      "kappa"
#  [625] "kappa.default"                      "kappa.lm"
#  [627] "kappa.qr"                           "kronecker"
#  [629] "l10n_info"                          "La_library"
#  [631] "La_version"                         "La.svd"
#  [633] "labels"                             "labels.default"
#  [635] "lapply"                             "lazyLoad"
#  [637] "lazyLoadDBexec"                     "lazyLoadDBfetch"
#  [639] "lbeta"                              "lchoose"
#  [641] "length"                             "length.POSIXlt"
#  [643] "length<-"                           "length<-.Date"
#  [645] "length<-.difftime"                  "length<-.factor"
#  [647] "length<-.POSIXct"                   "length<-.POSIXlt"
#  [649] "lengths"                            "letters"
#  [651] "LETTERS"                            "levels"
#  [653] "levels.default"                     "levels<-"
#  [655] "levels<-.factor"                    "lfactorial"
#  [657] "lgamma"                             "libcurlVersion"
#  [659] "library"                            "library.dynam"
#  [661] "library.dynam.unload"               "licence"
#  [663] "license"                            "list"
#  [665] "list.dirs"                          "list.files"
#  [667] "list2env"                           "load"
#  [669] "loadedNamespaces"                   "loadingNamespaceInfo"
#  [671] "loadNamespace"                      "local"
#  [673] "lockBinding"                        "lockEnvironment"
#  [675] "log"                                "log10"
#  [677] "log1p"                              "log2"
#  [679] "logb"                               "logical"
#  [681] "lower.tri"                          "ls"
#  [683] "make.names"                         "make.unique"
#  [685] "makeActiveBinding"                  "Map"
#  [687] "mapply"                             "margin.table"
#  [689] "mat.or.vec"                         "match"
#  [691] "match.arg"                          "match.call"
#  [693] "match.fun"                          "Math.data.frame"
#  [695] "Math.Date"                          "Math.difftime"
#  [697] "Math.factor"                        "Math.POSIXt"
#  [699] "matrix"                             "max"
#  [701] "max.col"                            "mean"
#  [703] "mean.Date"                          "mean.default"
#  [705] "mean.difftime"                      "mean.POSIXct"
#  [707] "mean.POSIXlt"                       "mem.limits"
#  [709] "memCompress"                        "memDecompress"
#  [711] "memory.profile"                     "merge"
#  [713] "merge.data.frame"                   "merge.default"
#  [715] "message"                            "mget"
#  [717] "min"                                "missing"
#  [719] "Mod"                                "mode"
#  [721] "mode<-"                             "month.abb"
#  [723] "month.name"                         "months"
#  [725] "months.Date"                        "months.POSIXt"
#  [727] "mostattributes<-"                   "names"
#  [729] "names.POSIXlt"                      "names<-"
#  [731] "names<-.POSIXlt"                    "namespaceExport"
#  [733] "namespaceImport"                    "namespaceImportClasses"
#  [735] "namespaceImportFrom"                "namespaceImportMethods"
#  [737] "nargs"                              "nchar"
#  [739] "ncol"                               "NCOL"
#  [741] "Negate"                             "new.env"
#  [743] "next"                               "NextMethod"
#  [745] "ngettext"                           "nlevels"
#  [747] "noquote"                            "norm"
#  [749] "normalizePath"                      "nrow"
#  [751] "NROW"                               "numeric"
#  [753] "numeric_version"                    "nzchar"
#  [755] "objects"                            "oldClass"
#  [757] "oldClass<-"                         "OlsonNames"
#  [759] "on.exit"                            "open"
#  [761] "open.connection"                    "open.srcfile"
#  [763] "open.srcfilealias"                  "open.srcfilecopy"
#  [765] "Ops.data.frame"                     "Ops.Date"
#  [767] "Ops.difftime"                       "Ops.factor"
#  [769] "Ops.numeric_version"                "Ops.ordered"
#  [771] "Ops.POSIXt"                         "options"
#  [773] "order"                              "ordered"
#  [775] "outer"                              "package_version"
#  [777] "packageEvent"                       "packageHasNamespace"
#  [779] "packageStartupMessage"              "packBits"
#  [781] "pairlist"                           "parent.env"
#  [783] "parent.env<-"                       "parent.frame"
#  [785] "parse"                              "parseNamespaceFile"
#  [787] "paste"                              "paste0"
#  [789] "path.expand"                        "path.package"
#  [791] "pcre_config"                        "pi"
#  [793] "pipe"                               "pmatch"
#  [795] "pmax"                               "pmax.int"
#  [797] "pmin"                               "pmin.int"
#  [799] "polyroot"                           "pos.to.env"
#  [801] "Position"                           "pretty"
#  [803] "pretty.default"                     "prettyNum"
#  [805] "print"                              "print.AsIs"
#  [807] "print.by"                           "print.condition"
#  [809] "print.connection"                   "print.data.frame"
#  [811] "print.Date"                         "print.default"
#  [813] "print.difftime"                     "print.Dlist"
#  [815] "print.DLLInfo"                      "print.DLLInfoList"
#  [817] "print.DLLRegisteredRoutines"        "print.eigen"
#  [819] "print.factor"                       "print.function"
#  [821] "print.hexmode"                      "print.libraryIQR"
#  [823] "print.listof"                       "print.NativeRoutineList"
#  [825] "print.noquote"                      "print.numeric_version"
#  [827] "print.octmode"                      "print.packageInfo"
#  [829] "print.POSIXct"                      "print.POSIXlt"
#  [831] "print.proc_time"                    "print.restart"
#  [833] "print.rle"                          "print.simple.list"
#  [835] "print.srcfile"                      "print.srcref"
#  [837] "print.summary.table"                "print.summary.warnings"
#  [839] "print.summaryDefault"               "print.table"
#  [841] "print.warnings"                     "prmatrix"
#  [843] "proc.time"                          "prod"
#  [845] "prop.table"                         "provideDimnames"
#  [847] "psigamma"                           "pushBack"
#  [849] "pushBackLength"                     "q"
#  [851] "qr"                                 "qr.coef"
#  [853] "qr.default"                         "qr.fitted"
#  [855] "qr.Q"                               "qr.qty"
#  [857] "qr.qy"                              "qr.R"
#  [859] "qr.resid"                           "qr.solve"
#  [861] "qr.X"                               "quarters"
#  [863] "quarters.Date"                      "quarters.POSIXt"
#  [865] "quit"                               "quote"
#  [867] "R_system_version"                   "R.home"
#  [869] "R.version"                          "R.Version"
#  [871] "R.version.string"                   "range"
#  [873] "range.default"                      "rank"
#  [875] "rapply"                             "raw"
#  [877] "rawConnection"                      "rawConnectionValue"
#  [879] "rawShift"                           "rawToBits"
#  [881] "rawToChar"                          "rbind"
#  [883] "rbind.data.frame"                   "rcond"
#  [885] "Re"                                 "read.dcf"
#  [887] "readBin"                            "readChar"
#  [889] "readline"                           "readLines"
#  [891] "readRDS"                            "readRenviron"
#  [893] "Recall"                             "Reduce"
#  [895] "reg.finalizer"                      "regexec"
#  [897] "regexpr"                            "registerS3method"
#  [899] "registerS3methods"                  "regmatches"
#  [901] "regmatches<-"                       "remove"
#  [903] "removeTaskCallback"                 "rep"
#  [905] "rep_len"                            "rep.Date"
#  [907] "rep.factor"                         "rep.int"
#  [909] "rep.numeric_version"                "rep.POSIXct"
#  [911] "rep.POSIXlt"                        "repeat"
#  [913] "replace"                            "replicate"
#  [915] "require"                            "requireNamespace"
#  [917] "restartDescription"                 "restartFormals"
#  [919] "retracemem"                         "return"
#  [921] "returnValue"                        "rev"
#  [923] "rev.default"                        "rle"
#  [925] "rm"                                 "RNGkind"
#  [927] "RNGversion"                         "round"
#  [929] "round.Date"                         "round.POSIXt"
#  [931] "row"                                "row.names"
#  [933] "row.names.data.frame"               "row.names.default"
#  [935] "row.names<-"                        "row.names<-.data.frame"
#  [937] "row.names<-.default"                "rowMeans"
#  [939] "rownames"                           "rownames<-"
#  [941] "rowsum"                             "rowsum.data.frame"
#  [943] "rowsum.default"                     "rowSums"
#  [945] "sample"                             "sample.int"
#  [947] "sapply"                             "save"
#  [949] "save.image"                         "saveRDS"
#  [951] "scale"                              "scale.default"
#  [953] "scan"                               "search"
#  [955] "searchpaths"                        "seek"
#  [957] "seek.connection"                    "seq"
#  [959] "seq_along"                          "seq_len"
#  [961] "seq.Date"                           "seq.default"
#  [963] "seq.int"                            "seq.POSIXt"
#  [965] "sequence"                           "serialize"
#  [967] "set.seed"                           "setdiff"
#  [969] "setequal"                           "setHook"
#  [971] "setNamespaceInfo"                   "setSessionTimeLimit"
#  [973] "setTimeLimit"                       "setwd"
#  [975] "showConnections"                    "shQuote"
#  [977] "sign"                               "signalCondition"
#  [979] "signif"                             "simpleCondition"
#  [981] "simpleError"                        "simpleMessage"
#  [983] "simpleWarning"                      "simplify2array"
#  [985] "sin"                                "single"
#  [987] "sinh"                               "sink"
#  [989] "sink.number"                        "sinpi"
#  [991] "slice.index"                        "socketConnection"
#  [993] "socketSelect"                       "solve"
#  [995] "solve.default"                      "solve.qr"
#  [997] "sort"                               "sort.default"
#  [999] "sort.int"                           "sort.list"
# [1001] "sort.POSIXlt"                       "source"
# [1003] "split"                              "split.data.frame"
# [1005] "split.Date"                         "split.default"
# [1007] "split.POSIXct"                      "split<-"
# [1009] "split<-.data.frame"                 "split<-.default"
# [1011] "sprintf"                            "sqrt"
# [1013] "sQuote"                             "srcfile"
# [1015] "srcfilealias"                       "srcfilecopy"
# [1017] "srcref"                             "standardGeneric"
# [1019] "startsWith"                         "stderr"
# [1021] "stdin"                              "stdout"
# [1023] "stop"                               "stopifnot"
# [1025] "storage.mode"                       "storage.mode<-"
# [1027] "strftime"                           "strptime"
# [1029] "strrep"                             "strsplit"
# [1031] "strtoi"                             "strtrim"
# [1033] "structure"                          "strwrap"
# [1035] "sub"                                "subset"
# [1037] "subset.data.frame"                  "subset.default"
# [1039] "subset.matrix"                      "substitute"
# [1041] "substr"                             "substr<-"
# [1043] "substring"                          "substring<-"
# [1045] "sum"                                "summary"
# [1047] "summary.connection"                 "summary.data.frame"
# [1049] "Summary.data.frame"                 "summary.Date"
# [1051] "Summary.Date"                       "summary.default"
# [1053] "Summary.difftime"                   "summary.factor"
# [1055] "Summary.factor"                     "summary.matrix"
# [1057] "Summary.numeric_version"            "Summary.ordered"
# [1059] "summary.POSIXct"                    "Summary.POSIXct"
# [1061] "summary.POSIXlt"                    "Summary.POSIXlt"
# [1063] "summary.proc_time"                  "summary.srcfile"
# [1065] "summary.srcref"                     "summary.table"
# [1067] "summary.warnings"                   "suppressMessages"
# [1069] "suppressPackageStartupMessages"     "suppressWarnings"
# [1071] "suspendInterrupts"                  "svd"
# [1073] "sweep"                              "switch"
# [1075] "sys.call"                           "sys.calls"
# [1077] "Sys.chmod"                          "Sys.Date"
# [1079] "sys.frame"                          "sys.frames"
# [1081] "sys.function"                       "Sys.getenv"
# [1083] "Sys.getlocale"                      "Sys.getpid"
# [1085] "Sys.glob"                           "Sys.info"
# [1087] "sys.load.image"                     "Sys.localeconv"
# [1089] "sys.nframe"                         "sys.on.exit"
# [1091] "sys.parent"                         "sys.parents"
# [1093] "Sys.readlink"                       "sys.save.image"
# [1095] "Sys.setenv"                         "Sys.setFileTime"
# [1097] "Sys.setlocale"                      "Sys.sleep"
# [1099] "sys.source"                         "sys.status"
# [1101] "Sys.time"                           "Sys.timezone"
# [1103] "Sys.umask"                          "Sys.unsetenv"
# [1105] "Sys.which"                          "system"
# [1107] "system.file"                        "system.time"
# [1109] "system2"                            "t"
# [1111] "T"                                  "t.data.frame"
# [1113] "t.default"                          "table"
# [1115] "tabulate"                           "tan"
# [1117] "tanh"                               "tanpi"
# [1119] "tapply"                             "taskCallbackManager"
# [1121] "tcrossprod"                         "tempdir"
# [1123] "tempfile"                           "testPlatformEquivalence"
# [1125] "textConnection"                     "textConnectionValue"
# [1127] "tolower"                            "topenv"
# [1129] "toString"                           "toString.default"
# [1131] "toupper"                            "trace"
# [1133] "traceback"                          "tracemem"
# [1135] "tracingState"                       "transform"
# [1137] "transform.data.frame"               "transform.default"
# [1139] "trigamma"                           "trimws"
# [1141] "trunc"                              "trunc.Date"
# [1143] "trunc.POSIXt"                       "truncate"
# [1145] "truncate.connection"                "try"
# [1147] "tryCatch"                           "typeof"
# [1149] "unclass"                            "undebug"
# [1151] "union"                              "unique"
# [1153] "unique.array"                       "unique.data.frame"
# [1155] "unique.default"                     "unique.matrix"
# [1157] "unique.numeric_version"             "unique.POSIXlt"
# [1159] "unique.warnings"                    "units"
# [1161] "units.difftime"                     "units<-"
# [1163] "units<-.difftime"                   "unix.time"
# [1165] "unlink"                             "unlist"
# [1167] "unloadNamespace"                    "unlockBinding"
# [1169] "unname"                             "unserialize"
# [1171] "unsplit"                            "untrace"
# [1173] "untracemem"                         "unz"
# [1175] "upper.tri"                          "url"
# [1177] "UseMethod"                          "utf8ToInt"
# [1179] "validEnc"                           "validUTF8"
# [1181] "vapply"                             "vector"
# [1183] "Vectorize"                          "version"
# [1185] "warning"                            "warnings"
# [1187] "weekdays"                           "weekdays.Date"
# [1189] "weekdays.POSIXt"                    "which"
# [1191] "which.max"                          "which.min"
# [1193] "while"                              "with"
# [1195] "with.default"                       "withAutoprint"
# [1197] "withCallingHandlers"                "within"
# [1199] "within.data.frame"                  "within.list"
# [1201] "withRestarts"                       "withVisible"
# [1203] "write"                              "write.dcf"
# [1205] "writeBin"                           "writeChar"
# [1207] "writeLines"                         "xor"
# [1209] "xpdrows.data.frame"                 "xtfrm"
# [1211] "xtfrm.AsIs"                         "xtfrm.Date"
# [1213] "xtfrm.default"                      "xtfrm.difftime"
# [1215] "xtfrm.factor"                       "xtfrm.numeric_version"
# [1217] "xtfrm.POSIXct"                      "xtfrm.POSIXlt"
# [1219] "xtfrm.Surv"                         "xzfile"
# [1221] "zapsmall"

# %% [markdown]
# 特定の環境のオブジェクトを指定する場合はRの$をしようする。

# %%
deck <- read.csv("deck.csv")

head(globalenv()$deck,3)
# Out:
#   face  suit   value
# 1 king  spades 13
# 2 queen spades 12
# 3 jack  spades 11

# %% [markdown]
# オブジェクトを特定の環境に格納するときは、assign関数を。(実質`<-`)

# %%
assign("new" , "hello global" ,envir = globalenv())

ls(globalenv())
globalenv()$new
# Out:
# [1] "a"    "deck" "new"
# [1] "hello global"

# %% [markdown]
# ### 6.2.1 アクティブな環境
# Rはいつも一つの環境と密接なやりとりをしている。<br>
# globalEnvでオブジェクトを管理しています。<br>
# このような環境のことを**アクティブ環境**と呼ぶことにします。<br>
# <br>
# アクティブ環境は`enviroment()`で確認することができます。

# %%
environment()
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# ## 6.3 スコープルール
# Rは一連の特別な規則に沿ってオブジェクトを検索している。
#
# 1. Rがアクティブ環境でオブジェクトを探す<br>
#
# 1. コマンドラインでの作業時は、アクティブ環境はグローバル環境である。<br>なのでコマンドラインで呼び出したオブジェクトはグローバル環境で検索される<br>
#
# 1. ある環境でオブジェクトが見つからなければ、Rはその環境の親環境で検索する。<br>そこでなければその親に……そしてさらに親にと、親を遡る。<br>オブジェクト発見か空環境に到達するまで検索は続く。

# %% [markdown]
# ## 6.4 割り当て
# オブジェクトに値を割り当てると、Rはアクティブ環境でオブジェクトの名の下にその値を格納します。<br>
# アクティブ環境にすでに同名のオブジェクトが存在する場合には、<br>
# Rはそれを上書きします。

# %%
new
# Out:
# [1] "hello global"

# %%
new <- "hello active"
new
# Out:
# [1] "hello active"

# %% [markdown]
# たまにコレが問題になるそうです。<br>
# 多くの関数は、動作の便宜上、一時的にオブジェクトを保存しています。<br>
# 下記の`roll関数`は`die`と`dice`をオブジェクトとして保存していました。

# %%
roll <-function(){
    die <- 1:6
    dice <- sample(die , size = ２, replace = T)
    sum(dice)
}

# %% [markdown]
# Rはコレらのオブジェクトを一時オブジェクトとしてアクティブ環境に格納しなくてはいけません。<br>
# しかし、そのように動作すると既存のオブジェクトを上書きしてしまう可能性があります。<br>
# 関数の作者はそんなこと考えていません。<br>
# <br>
# このようなリスクを回避するために、関数を実行するたびにRは関数を評価するための新しいアクティブ環境を作成します。

# %% [markdown]
# ## 6.5 評価
# Rは関数を評価するたびに新しい環境を作ります。<br>
# 関数を実行している間はこの新しい環境をアクティブ環境として使い、
# <br>監修の実行が終了すると関数の実行結果を返し、もとの実行環境に戻ります。

# %%
show_env <- function(){
    list(ran.in = environment(), #実行環境
        parent = parent.env(environment())  , #親環境
        objects = ls.str(environment())) # 格納されているオブジェクト
}

# %%
show_env()
# Out:
# $ran.in
# <environment: 0x564affd926e0>
#
# $parent
# <environment: R_GlobalEnv>
#
# $objects

# %% [markdown]
# 複数回`show_env`を動かすとわかりますが　……<br>
# `ran.in`で表示されている環境が毎回違います。<br>
# 関数のアクティブ環境が毎回新しく作成されているのです。<br>

# %% [markdown]
# Rが実行環境で使う環境は、環境が**最初に作成された環境**に実行環境を作成します。<br>
# この環境は関数の全ての実行環境が親として使用するものであり、<br>
# 関数にとって重要な役割を持ちます。<br>
# この環境を参考書籍では**オリジン環境**と呼称しています。

# %%
environment(show_env)
# Out:
# <environment: R_GlobalEnv>

# %% [markdown]
# `show_env`は上記のようにglobalenvが親環境として使用されています。<br>
# しかし、必ずGlobalenvである必要はありません。<br>

# %%
environment(parenv)
# Out:
# <environment: namespace:pryr>

# %%
show_env <- function(){
    a <- 1
    b <- 2
    c <- 3

    list(ran.in = environment(), #実行環境
        parent = parent.env(environment())  , #親環境
        objects = ls.str(environment())) # 格納されているオブジェクト
}

# %%
show_env()
# Out:
# $ran.in
# <environment: 0x564afc71cd68>
#
# $parent
# <environment: R_GlobalEnv>
#
# $objects
# a :  num 1
# b :  num 2
# c :  num 3

# %%
foo <- "take on me your runtime!"

show_env <- function(x = foo){
    list(ran.in = environment(), #実行環境
        parent = parent.env(environment())  , #親環境
        objects = ls.str(environment())) # 格納されているオブジェクト
}

show_env()
# Out:
# $ran.in
# <environment: 0x564b012411a8>
#
# $parent
# <environment: R_GlobalEnv>
#
# $objects
# x :  chr "take on me your runtime!"

# %% [markdown]
# 関数を呼び出す前、Rはアクティブ環境で仕事をしています。<br>
# 参考書籍では**呼び出し元環境**と呼称しています。<br>
# <br>
# 関数が呼び出されると、アクティブ環境を親環境にして関数用の実行環境が用意されます。<br>
# コード実行時にオブジェクトがあればアクティブ環境である実行環境に格納します。<br>
# Rはスコープルールに沿ってオブジェクトを検索するので、<br>
# 検索しているオブジェクトが実行環境に存在しない場合は親環境を、<br>
# なければその親環境を……という風に検索されます。<br>
#
# ここで注意する点はオリジン環境は検索パスに入っていない点です。<br>
# 通常、関数は引数しか呼び出しません。<br>
# 引数はアクティブになっている実行環境で見つけることができます。<br>

# %% [markdown]
# ***
# **練習問題**<br>
# 新バージョンの`deal()`を呼び出したとき、Rはdeckを発見することが可能か？<br>
# <br>
# A.できる

# %%
deal <- function(){
    deck[1, ]
}
environment(deal)
# Out:
# <environment: R_GlobalEnv>

# %%
deal()
# Out:
#   face suit   value
# 1 king spades 13

# %% [markdown]
# 現状のままでは、deal関数は何度実行しても同じカードを返すのみです。<br>
# 今回は一度配ったカードを取り除くように工夫をしましょう。

# %%
DECK <- deck 

deck <- deck[-1, ]

head(deck)
# Out:
#   face  suit   value
# 2 queen spades 12
# 3 jack  spades 11
# 4 ten   spades 10
# 5 nine  spades  9
# 6 eight spades  8
# 7 seven spades  7

# %% [markdown]
# 下記の関数は動作しません。<br>
# `deck <- deck[-1, ]`のときに実行環境で処理を行なっているため、<br>
# 元の方のdeckは何も変更されていないのです

# %%
deal <- function() {
    card <- deck[1, ]
    deck <- deck[-1, ]
    card
}

deal()
# Out:
#   face  suit   value
# 2 queen spades 12

# %% [markdown]
# ***
# **練習問題**<br>
# dealの`deck <- [-1, ]`を書き直し、グローバル環境のdeckに`deck <- deck[-1, ]`を書き直してください。<br>
# hint : assign()

# %%
deal <- function(){
    card <- deck[1, ]
     assign("deck" , deck[-1, ], envir = globalenv())# dekc <- deck[-1, ]
    card
}

# %%
deal() #繰り返し実行することで順番に減っていく。
# Out:
#   face suit   value
# 3 jack spades 11

# %% [markdown]
# 次はshaffle関数です。<br>
# 以前に記述している通り、shaffle()は実際にdeckをシャッフルしていません。<br>
# deckのコピーを用意してshaffleしています。

# %%
# 現状
shaffle <- function(cards){
    random <- sample(1:52, size = 52)
    cards[random, ]
}

# %%
shaffle(deck)
# Out:
#    face  suit     value
# 51 two   hearts    2
# 26 ace   clubs     1
# 6  eight spades    8
# 34 six   diamonds  6
# 39 ace   diamonds  1
# 31 nine  diamonds  9
# 44 nine  hearts    9
# 13 ace   spades    1
# 9  five  spades    5
# 12 two   spades    2
# 24 three clubs     3
# 19 eight clubs     8
# 43 ten   hearts   10
# 20 seven clubs     7
# 21 six   clubs     6
# 35 five  diamonds  5
# 2  queen spades   12
# 15 queen clubs    12
# 32 eight diamonds  8
# 47 six   hearts    6
# 36 four  diamonds  4
# 18 nine  clubs     9
# 8  six   spades    6
# 49 four  hearts    4
# 38 two   diamonds  2
# 5  nine  spades    9
# 17 ten   clubs    10
# 1  king  spades   13
# 52 ace   hearts    1
# 10 four  spades    4
# 23 four  clubs     4
# 27 king  diamonds 13
# 16 jack  clubs    11
# 29 jack  diamonds 11
# 41 queen hearts   12
# 30 ten   diamonds 10
# 25 two   clubs     2
# 48 five  hearts    5
# 3  jack  spades   11
# 46 seven hearts    7
# 4  ten   spades   10
# 37 three diamonds  3
# 40 king  hearts   13
# 22 five  clubs     5
# 33 seven diamonds  7
# 7  seven spades    7
# 28 queen diamonds 12
# 14 king  clubs    13
# 42 jack  hearts   11
# 50 three hearts    3
# 45 eight hearts    8
# 11 three spades    3

# %%
head(deck , 3)
# Out:
#   face  suit   value
# 1 king  spades 13
# 2 queen spades 12
# 3 jack  spades 11

# %% [markdown]
# ***
# **練習問題**<br>
# グローバル環境のdeckをシャッフルしたDECKに置き換えるようにshufleを書き換えてください。<br>
# 新バージョンは引数を取らず、出力も返さないものとする。

# %%
shuffle <- function(){
    random <- sample(1:52, size = 52)
    assign("deck" , DECK[random, ] , envir = globalenv())
}

# %%
shuffle()
head(deck)
# Out:
#    face  suit     value
# 13 ace   spades    1
# 29 jack  diamonds 11
# 10 four  spades    4
# 19 eight clubs     8
# 12 two   spades    2
# 49 four  hearts    4

# %% [markdown]
# ## 6.6 クロージャー

# %% [markdown]
# やりました！これでカードのシャッフルとディールが可能になりました！

# %%
shuffle()
deal()
# Out:
#    face suit  value
# 23 four clubs 4

# %% [markdown]
# このシステムにも欠点があります。<br>
# グローバル環境に`deck`と`DECK`がないと動作しないのです。<br>
# この環境では多くのことが起きるので、deckが誤って書き換えられる可能性があります。<br>
# <br>
# Rが関数を実行するために作る隔離環境のように、安全な場所でdeckを格納できる方法はないのでしょうか？<br>
# <br>
# 例えば引数としてdeckを取り、それのコピーであるDECKとして保存する方法があります。

# %%
setup <- function(deck) {
  DECK <- deck

  DEAL <- function() {
    card <- deck[1, ]
    assign("deck", deck[-1, ], envir = globalenv())
    card
  }

  SHUFFLE <- function(){
    random <- sample(1:52, size = 52)
    assign("deck", DECK[random, ], envir = globalenv())
 }
}

# %%
setup <- function(deck) {
  DECK <- deck

  DEAL <- function() {
    card <- deck[1, ]
    assign("deck", deck[-1, ], envir = globalenv())
    card
  }

  SHUFFLE <- function(){
    random <- sample(1:52, size = 52)
    assign("deck", DECK[random, ], envir = globalenv())
 }

 list(deal = DEAL, shuffle = SHUFFLE)
}

cards <- setup(deck)

# %%
deal <- cards$deal
shuffle <- cards$shuffle

# %%
environment(deal)
# Out:
# <environment: 0x564afe49ae78>
